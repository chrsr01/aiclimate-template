# %% [markdown]
# # {{ aiclimate.project_name }} - Data Exploration
#
# {{ aiclimate.project_description }}

# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

# %% [markdown]
# ## Load Data

# %%
# Load your climate/environmental data here
# ds = xr.open_dataset('data/raw/your_data.nc')
